# %%
import pandas as pd

# %% [markdown]
# # Import
# -   scaling
# -   preprocess

# %%
train_df= pd.read_excel('data/train.xlsx')
validation_df = pd.read_excel("data/validation.xlsx")

# %% [markdown]
# # Magic
# -   scaling
# -   remove unneccessary columns if any, e.g. PCA, stb

# %%
train = train_df.copy()
validation = validation_df.copy()

# %%
train.shape
# Out:
# (13285, 87)

# %%
validation.shape
# Out:
# (13, 86)

# %%
target = train["red_fighter_win"]
train = train.drop(columns = ["red_fighter_win"])

# %%
def add_fighter_ages(df):
    """
    Calculate and add fighter ages based on event_date and fighter date of birth.
    
    Parameters:
    -----------
    df : pandas.DataFrame
        DataFrame containing UFC fight data with columns:
        - event_date: date of the fight
        - red_fighter_dob: date of birth for red corner fighter
        - blue_fighter_dob: date of birth for blue corner fighter
    
    Returns:
    --------
    pandas.DataFrame
        The input DataFrame with two new columns added:
        - red_fighter_age: age of red corner fighter at time of fight
        - blue_fighter_age: age of blue corner fighter at time of fight
    """
    # Create a copy of the dataframe to avoid modifying the original
    df_copy = df.copy()
    
    # Calculate age in years for red fighter
    df_copy['red_fighter_age'] = (df_copy['event_date'] - df_copy['red_fighter_dob']).dt.days / 365.25
    
    # Calculate age in years for blue fighter
    df_copy['blue_fighter_age'] = (df_copy['event_date'] - df_copy['blue_fighter_dob']).dt.days / 365.25
    
    # Round ages to 1 decimal place for better readability
    df_copy['red_fighter_age'] = df_copy['red_fighter_age'].round(1)
    df_copy['blue_fighter_age'] = df_copy['blue_fighter_age'].round(1)
    
    return df_copy

# Example usage:
train = add_fighter_ages(train)
validation = add_fighter_ages(validation)

train = train.drop(columns = ["red_fighter_dob", "blue_fighter_dob", "event_date"])
validation = validation.drop(columns = ["red_fighter_dob", "blue_fighter_dob", "event_date"])

# %%
def compare_column_distributions(train_df, val_df, columns=None, verbose=True):
    """
    Compare the distributions of columns between training and validation datasets
    to check if they're in similar ranges and likely using the same units.
    
    Parameters:
    -----------
    train_df : pandas.DataFrame
        Training dataset
    val_df : pandas.DataFrame
        Validation dataset
    columns : list or None
        List of columns to compare. If None, compares all numeric columns
    verbose : bool
        Whether to print detailed information
        
    Returns:
    --------
    dict
        Dictionary with column names as keys and comparison results as values
        Each result contains min, max, mean, median, and std for both datasets
    """
    import numpy as np
    
    # If no columns specified, use all numeric columns
    if columns is None:
        numeric_dtypes = ['int16', 'int32', 'int64', 'float16', 'float32', 'float64']
        columns = [col for col in train_df.columns if train_df[col].dtype.name in numeric_dtypes]
    
    results = {}
    potential_issues = []
    
    for col in columns:
        # Skip if column doesn't exist in both dataframes
        if col not in train_df.columns or col not in val_df.columns:
            if verbose:
                print(f"Column '{col}' not found in both datasets. Skipping.")
            continue
            
        # Skip non-numeric columns
        if not np.issubdtype(train_df[col].dtype, np.number) or not np.issubdtype(val_df[col].dtype, np.number):
            if verbose:
                print(f"Column '{col}' is not numeric in one or both datasets. Skipping.")
            continue
        
        # Calculate statistics
        train_stats = {
            'min': train_df[col].min(),
            'max': train_df[col].max(),
            'mean': train_df[col].mean(),
            'median': train_df[col].median(),
            'std': train_df[col].std()
        }
        
        val_stats = {
            'min': val_df[col].min(),
            'max': val_df[col].max(),
            'mean': val_df[col].mean(),
            'median': val_df[col].median(),
            'std': val_df[col].std()
        }
        
        # Store results
        results[col] = {
            'train': train_stats,
            'validation': val_stats
        }
        
        # Check for potential issues
        # 1. Check if ranges are completely different
        if (val_stats['min'] > train_stats['max']) or (val_stats['max'] < train_stats['min']):
            potential_issues.append(f"WARNING: Column '{col}' has non-overlapping ranges between train and validation")
        
        # 2. Check if means are very different (more than 3 std deviations apart)
        mean_diff = abs(train_stats['mean'] - val_stats['mean'])
        mean_threshold = 3 * max(train_stats['std'], val_stats['std'])
        if mean_diff > mean_threshold:
            potential_issues.append(f"WARNING: Column '{col}' has significantly different means between train and validation")
        
        # 3. Check if one dataset has much higher variance
        std_ratio = max(train_stats['std'], val_stats['std']) / (min(train_stats['std'], val_stats['std']) + 1e-10)
        if std_ratio > 5:  # Arbitrary threshold
            potential_issues.append(f"WARNING: Column '{col}' has much higher variance in one dataset (ratio: {std_ratio:.2f})")
    
    # Print results if verbose
    if verbose:
        print("\n=== Column Distribution Comparison ===\n")
        for col, stats in results.items():
            print(f"Column: {col}")
            print(f"  Train:      min={stats['train']['min']:.2f}, max={stats['train']['max']:.2f}, mean={stats['train']['mean']:.2f}, median={stats['train']['median']:.2f}, std={stats['train']['std']:.2f}")
            print(f"  Validation: min={stats['validation']['min']:.2f}, max={stats['validation']['max']:.2f}, mean={stats['validation']['mean']:.2f}, median={stats['validation']['median']:.2f}, std={stats['validation']['std']:.2f}")
            print()
        
        if potential_issues:
            print("\n=== Potential Issues Detected ===\n")
            for issue in potential_issues:
                print(issue)
    
    return results

# Example usage:
comparison_results = compare_column_distributions(train, validation)

# To check specific columns like height and weight:
# height_weight_comparison = compare_column_distributions(
#     train, validation, 
#     columns=['red_fighter_height', 'blue_fighter_height', 'red_fighter_weight', 'blue_fighter_weight']
# )
# Out:
# === Column Distribution Comparison ===
#
# Column: red_body_attempted_weighted_trailing
#   Train:      min=0.00, max=35.82, mean=4.24, median=3.41, std=3.87
#   Validation: min=1.00, max=14.86, mean=6.38, median=6.00, std=4.58
#
# Column: red_body_landed_weighted_trailing
#   Train:      min=0.00, max=30.16, mean=2.96, median=2.32, std=2.84
#   Validation: min=0.00, max=9.24, mean=4.25, median=4.73, std=2.93
#
# Column: red_clinch_attempted_weighted_trailing
#   Train:      min=0.00, max=39.00, mean=2.82, median=1.73, std=3.51
#   Validation: min=0.00, max=6.63, mean=2.03, median=1.10, std=2.19
#
# Column: red_clinch_landed_weighted_trailing
#   Train:      min=0.00, max=30.00, mean=1.96, median=1.09, std=2.56
#   Validation: min=0.00, max=6.36, mean=1.64, median=0.84, std=1.96
#
# Column: red_ctrl_weighted_trailing
#   Train:      min=0.00, max=295.00, mean=53.18, median=30.35, std=59.89
#   Validation: min=0.00, max=173.25, mean=84.57, median=84.58, std=55.66
#
# Column: red_distance_attempted_weighted_trailing
#   Train:      min=0.00, max=159.10, mean=26.21, median=23.00, std=20.97
#   Validation: min=5.87, max=46.71, mean=25.00, median=26.46, std=15.68
#
# Column: red_distance_landed_weighted_trailing
#   Train:      min=0.00, max=103.38, mean=10.35, median=8.38, std=9.21
#   Validation: min=2.35, max=24.85, mean=11.66, median=10.21, std=6.95
#
# Column: red_fighter_avg_fight_time
#   Train:      min=0.00, max=1500.00, mean=535.10, median=571.00, std=267.79
#   Validation: min=374.00, max=1042.00, mean=718.85, median=675.00, std=183.80
#
# Column: red_fighter_days_since_last
#   Train:      min=0.00, max=3199.00, mean=114.66, median=77.00, std=175.81
#   Validation: min=119.00, max=735.00, mean=281.62, median=238.00, std=178.74
#
# Column: red_fighter_defense
#   Train:      min=-23.00, max=1.00, mean=0.50, median=0.60, std=0.60
#   Validation: min=0.40, max=0.67, mean=0.53, median=0.53, std=0.07
#
# Column: red_fighter_height
#   Train:      min=152.00, max=211.00, mean=178.19, median=178.00, std=8.97
#   Validation: min=163.00, max=190.00, mean=177.38, median=180.00, std=10.32
#
# Column: red_fighter_losses
#   Train:      min=0.00, max=18.00, mean=2.31, median=2.00, std=2.47
#   Validation: min=0.00, max=10.00, mean=4.38, median=4.00, std=3.07
#
# Column: red_fighter_reach
#   Train:      min=58.00, max=84.00, mean=71.94, median=72.00, std=4.24
#   Validation: min=62.00, max=79.00, mean=72.00, median=72.00, std=5.31
#
# Column: red_fighter_strikes_absorbed_per_min
#   Train:      min=0.00, max=75.45, mean=3.24, median=2.99, std=2.64
#   Validation: min=0.96, max=4.72, mean=3.18, median=3.37, std=0.97
#
# Column: red_fighter_strikes_landed_per_min
#   Train:      min=0.00, max=61.60, mean=3.78, median=3.53, std=3.02
#   Validation: min=1.84, max=5.75, mean=3.61, median=3.57, std=1.21
#
# Column: red_fighter_striking_accuracy
#   Train:      min=0.00, max=1.00, mean=0.42, median=0.45, std=0.16
#   Validation: min=0.40, max=0.70, mean=0.50, median=0.49, std=0.09
#
# Column: red_fighter_submission_per_15
#   Train:      min=0.00, max=56.25, mean=0.90, median=0.36, std=1.89
#   Validation: min=0.00, max=2.40, mean=0.40, median=0.10, std=0.67
#
# Column: red_fighter_takedown_accuracy
#   Train:      min=0.00, max=1.00, mean=0.37, median=0.38, std=0.28
#   Validation: min=0.00, max=0.66, mean=0.30, median=0.33, std=0.22
#
# Column: red_fighter_takedown_defense
#   Train:      min=0.00, max=1.00, mean=0.54, median=0.61, std=0.32
#   Validation: min=0.00, max=1.00, mean=0.62, median=0.66, std=0.24
#
# Column: red_fighter_takedowns_per_15
#   Train:      min=0.00, max=42.86, mean=1.89, median=1.31, std=2.32
#   Validation: min=0.00, max=9.63, mean=1.56, median=1.09, std=2.52
#
# Column: red_fighter_weight
#   Train:      min=115.00, max=345.00, mean=166.47, median=155.00, std=35.40
#   Validation: min=115.00, max=249.00, mean=159.92, median=155.00, std=37.61
#
# Column: red_fighter_wins
#   Train:      min=0.00, max=26.00, mean=4.27, median=3.00, std=4.17
#   Validation: min=6.00, max=29.00, mean=15.54, median=13.00, std=7.11
#
# Column: red_ground_attempted_weighted_trailing
#   Train:      min=0.00, max=84.00, mean=2.98, median=1.00, std=4.97
#   Validation: min=0.00, max=12.00, mean=3.19, median=1.96, std=3.63
#
# Column: red_ground_landed_weighted_trailing
#   Train:      min=0.00, max=46.05, mean=2.04, median=0.67, std=3.41
#   Validation: min=0.00, max=7.26, mean=2.40, median=1.31, std=2.69
#
# Column: red_head_attempted_weighted_trailing
#   Train:      min=0.00, max=151.00, mean=24.91, median=23.10, std=17.89
#   Validation: min=8.06, max=32.33, mean=20.51, median=21.30, std=8.49
#
# Column: red_head_landed_weighted_trailing
#   Train:      min=0.00, max=80.43, mean=9.09, median=7.86, std=7.34
#   Validation: min=4.26, max=17.59, mean=9.03, median=8.82, std=3.44
#
# Column: red_kd_weighted_trailing
#   Train:      min=0.00, max=3.00, mean=0.08, median=0.00, std=0.20
#   Validation: min=0.00, max=0.50, mean=0.09, median=0.00, std=0.17
#
# Column: red_leg_attempted_weighted_trailing
#   Train:      min=0.00, max=42.00, mean=2.85, median=1.91, std=3.18
#   Validation: min=0.12, max=9.49, mean=3.34, median=2.23, std=3.36
#
# Column: red_leg_landed_weighted_trailing
#   Train:      min=0.00, max=27.00, mean=2.30, median=1.55, std=2.59
#   Validation: min=0.12, max=7.82, mean=2.42, median=2.14, std=2.23
#
# Column: red_rev_weighted_trailing
#   Train:      min=0.00, max=2.00, mean=0.05, median=0.00, std=0.16
#   Validation: min=0.00, max=0.75, mean=0.10, median=0.00, std=0.24
#
# Column: red_sig_str_attempted_weighted_trailing
#   Train:      min=0.00, max=161.16, mean=32.00, median=30.54, std=21.73
#   Validation: min=10.23, max=49.16, mean=30.22, median=29.52, std=14.59
#
# Column: red_sig_str_landed_weighted_trailing
#   Train:      min=0.00, max=105.27, mean=14.35, median=13.29, std=10.25
#   Validation: min=5.76, max=30.93, mean=15.70, median=15.67, std=6.62
#
# Column: red_sig_str_pct_weighted_trailing
#   Train:      min=0.00, max=1.00, mean=0.40, median=0.43, std=0.19
#   Validation: min=0.38, max=0.77, mean=0.55, median=0.51, std=0.14
#
# Column: red_sub_att_weighted_trailing
#   Train:      min=0.00, max=4.00, mean=0.15, median=0.00, std=0.34
#   Validation: min=0.00, max=0.56, mean=0.10, median=0.00, std=0.20
#
# Column: red_td_attempted_weighted_trailing
#   Train:      min=0.00, max=10.00, mean=1.09, median=0.67, std=1.25
#   Validation: min=0.31, max=4.00, mean=1.34, median=1.04, std=1.04
#
# Column: red_td_landed_weighted_trailing
#   Train:      min=0.00, max=5.26, mean=0.43, median=0.14, std=0.59
#   Validation: min=0.00, max=3.00, mean=0.54, median=0.16, std=0.82
#
# Column: red_td_pct_weighted_trailing
#   Train:      min=0.00, max=1.00, mean=0.21, median=0.08, std=0.27
#   Validation: min=0.00, max=0.89, mean=0.24, median=0.06, std=0.30
#
# Column: red_total_str_attempted_weighted_trailing
#   Train:      min=0.00, max=166.00, mean=39.97, median=40.17, std=23.80
#   Validation: min=18.33, max=81.00, mean=47.00, median=45.67, std=15.66
#
# Column: red_total_str_landed_weighted_trailing
#   Train:      min=0.00, max=118.00, mean=21.34, median=20.63, std=13.91
#   Validation: min=14.17, max=48.00, mean=30.36, median=24.34, std=11.33
#
# Column: blue_body_attempted_weighted_trailing
#   Train:      min=0.00, max=29.29, mean=3.71, median=2.76, std=3.94
#   Validation: min=0.00, max=21.00, mean=5.19, median=3.73, std=5.50
#
# Column: blue_body_landed_weighted_trailing
#   Train:      min=0.00, max=29.29, mean=2.60, median=1.83, std=2.89
#   Validation: min=0.00, max=17.00, mean=3.81, median=2.79, std=4.32
#
# Column: blue_clinch_attempted_weighted_trailing
#   Train:      min=0.00, max=43.67, mean=2.61, median=1.36, std=3.61
#   Validation: min=0.00, max=3.14, mean=1.09, median=1.14, std=0.89
#
# Column: blue_clinch_landed_weighted_trailing
#   Train:      min=0.00, max=33.00, mean=1.82, median=0.91, std=2.66
#   Validation: min=0.00, max=1.96, mean=0.71, median=0.67, std=0.59
#
# Column: blue_ctrl_weighted_trailing
#   Train:      min=0.00, max=294.00, mean=46.02, median=22.00, std=58.09
#   Validation: min=0.00, max=118.12, mean=33.65, median=21.71, std=40.03
#
# Column: blue_distance_attempted_weighted_trailing
#   Train:      min=0.00, max=138.26, mean=22.31, median=18.33, std=21.09
#   Validation: min=0.00, max=61.67, mean=32.57, median=33.63, std=20.96
#
# Column: blue_distance_landed_weighted_trailing
#   Train:      min=0.00, max=71.33, mean=8.84, median=6.67, std=9.02
#   Validation: min=0.00, max=30.33, mean=16.20, median=15.02, std=9.97
#
# Column: blue_fighter_avg_fight_time
#   Train:      min=0.00, max=1500.00, mean=463.07, median=511.00, std=307.74
#   Validation: min=414.00, max=900.00, mean=684.23, median=618.00, std=209.46
#
# Column: blue_fighter_days_since_last
#   Train:      min=0.00, max=4180.00, mean=106.23, median=0.00, std=204.62
#   Validation: min=0.00, max=287.00, mean=162.62, median=196.00, std=91.23
#
# Column: blue_fighter_defense
#   Train:      min=-41.00, max=1.00, mean=0.39, median=0.55, std=0.97
#   Validation: min=0.41, max=0.71, mean=0.53, median=0.50, std=0.09
#
# Column: blue_fighter_height
#   Train:      min=152.00, max=211.00, mean=178.11, median=178.00, std=8.87
#   Validation: min=163.00, max=193.00, mean=177.85, median=175.00, std=11.09
#
# Column: blue_fighter_losses
#   Train:      min=0.00, max=16.00, mean=1.70, median=1.00, std=2.01
#   Validation: min=0.00, max=13.00, mean=3.54, median=2.00, std=3.89
#
# Column: blue_fighter_reach
#   Train:      min=58.00, max=84.00, mean=71.75, median=71.00, std=4.04
#   Validation: min=59.00, max=81.00, mean=72.15, median=72.00, std=5.91
#
# Column: blue_fighter_strikes_absorbed_per_min
#   Train:      min=0.00, max=78.75, mean=3.04, median=2.81, std=3.16
#   Validation: min=0.86, max=5.62, mean=3.80, median=3.78, std=1.25
#
# Column: blue_fighter_strikes_landed_per_min
#   Train:      min=0.00, max=49.09, mean=3.29, median=3.18, std=2.99
#   Validation: min=3.04, max=7.20, mean=5.15, median=4.91, std=1.31
#
# Column: blue_fighter_striking_accuracy
#   Train:      min=0.00, max=1.00, mean=0.37, median=0.43, std=0.21
#   Validation: min=0.37, max=0.68, mean=0.51, median=0.51, std=0.09
#
# Column: blue_fighter_submission_per_15
#   Train:      min=0.00, max=51.92, mean=0.81, median=0.08, std=1.98
#   Validation: min=0.00, max=1.10, mean=0.41, median=0.30, std=0.40
#
# Column: blue_fighter_takedown_accuracy
#   Train:      min=0.00, max=1.00, mean=0.31, median=0.31, std=0.29
#   Validation: min=0.00, max=1.00, mean=0.50, median=0.50, std=0.32
#
# Column: blue_fighter_takedown_defense
#   Train:      min=0.00, max=1.00, mean=0.45, median=0.53, std=0.35
#   Validation: min=0.00, max=1.00, mean=0.57, median=0.62, std=0.36
#
# Column: blue_fighter_takedowns_per_15
#   Train:      min=0.00, max=100.00, mean=1.62, median=0.91, std=2.79
#   Validation: min=0.00, max=3.53, mean=1.73, median=1.49, std=1.30
#
# Column: blue_fighter_weight
#   Train:      min=115.00, max=770.00, mean=166.00, median=155.00, std=35.57
#   Validation: min=115.00, max=265.00, mean=161.15, median=155.00, std=40.88
#
# Column: blue_fighter_wins
#   Train:      min=0.00, max=26.00, mean=2.95, median=2.00, std=3.50
#   Validation: min=8.00, max=26.00, mean=12.85, median=11.00, std=5.34
#
# Column: blue_ground_attempted_weighted_trailing
#   Train:      min=0.00, max=70.00, mean=2.56, median=0.66, std=4.67
#   Validation: min=0.00, max=3.65, mean=0.82, median=0.14, std=1.32
#
# Column: blue_ground_landed_weighted_trailing
#   Train:      min=0.00, max=41.00, mean=1.75, median=0.41, std=3.19
#   Validation: min=0.00, max=3.10, mean=0.62, median=0.09, std=1.05
#
# Column: blue_head_attempted_weighted_trailing
#   Train:      min=0.00, max=126.40, mean=21.32, median=19.37, std=18.45
#   Validation: min=0.00, max=49.82, mean=23.66, median=22.87, std=16.18
#
# Column: blue_head_landed_weighted_trailing
#   Train:      min=0.00, max=56.52, mean=7.83, median=6.72, std=7.36
#   Validation: min=0.00, max=19.17, mean=9.50, median=10.74, std=6.68
#
# Column: blue_kd_weighted_trailing
#   Train:      min=0.00, max=2.12, mean=0.07, median=0.00, std=0.19
#   Validation: min=0.00, max=0.15, mean=0.01, median=0.00, std=0.04
#
# Column: blue_leg_attempted_weighted_trailing
#   Train:      min=0.00, max=28.00, mean=2.45, median=1.39, std=3.10
#   Validation: min=0.00, max=17.67, mean=5.62, median=3.60, std=5.31
#
# Column: blue_leg_landed_weighted_trailing
#   Train:      min=0.00, max=24.00, mean=1.99, median=1.10, std=2.54
#   Validation: min=0.00, max=11.67, mean=4.22, median=3.43, std=3.59
#
# Column: blue_rev_weighted_trailing
#   Train:      min=0.00, max=4.00, mean=0.05, median=0.00, std=0.16
#   Validation: min=0.00, max=0.58, mean=0.05, median=0.00, std=0.16
#
# Column: blue_sig_str_attempted_weighted_trailing
#   Train:      min=0.00, max=139.35, mean=27.48, median=26.00, std=22.76
#   Validation: min=0.00, max=64.83, mean=34.48, median=35.31, std=21.57
#
# Column: blue_sig_str_landed_weighted_trailing
#   Train:      min=0.00, max=71.99, mean=12.41, median=11.49, std=10.58
#   Validation: min=0.00, max=30.67, mean=17.52, median=15.94, std=10.35
#
# Column: blue_sig_str_pct_weighted_trailing
#   Train:      min=0.00, max=1.00, mean=0.35, median=0.41, std=0.23
#   Validation: min=0.00, max=0.61, mean=0.44, median=0.49, std=0.20
#
# Column: blue_sub_att_weighted_trailing
#   Train:      min=0.00, max=5.00, mean=0.14, median=0.00, std=0.33
#   Validation: min=0.00, max=0.33, mean=0.08, median=0.00, std=0.12
#
# Column: blue_td_attempted_weighted_trailing
#   Train:      min=0.00, max=11.00, mean=0.93, median=0.43, std=1.23
#   Validation: min=0.00, max=3.34, mean=1.14, median=0.52, std=1.25
#
# Column: blue_td_landed_weighted_trailing
#   Train:      min=0.00, max=5.00, mean=0.37, median=0.03, std=0.59
#   Validation: min=0.00, max=1.42, mean=0.47, median=0.14, std=0.56
#
# Column: blue_td_pct_weighted_trailing
#   Train:      min=0.00, max=1.00, mean=0.18, median=0.02, std=0.26
#   Validation: min=0.00, max=0.82, mean=0.19, median=0.07, std=0.24
#
# Column: blue_total_str_attempted_weighted_trailing
#   Train:      min=0.00, max=150.00, mean=34.74, median=35.87, std=26.00
#   Validation: min=0.00, max=69.24, mean=41.54, median=39.35, std=22.23
#
# Column: blue_total_str_landed_weighted_trailing
#   Train:      min=0.00, max=104.00, mean=18.78, median=18.73, std=14.95
#   Validation: min=0.00, max=53.81, mean=23.74, median=25.29, std=13.59
#
# Column: red_fighter_age
#   Train:      min=8.00, max=47.20, mean=30.52, median=30.40, std=4.44
#   Validation: min=25.80, max=42.10, mean=33.22, median=33.20, std=4.75
#
# Column: blue_fighter_age
#   Train:      min=7.40, max=51.90, mean=29.94, median=29.90, std=4.49
#   Validation: min=24.50, max=34.40, mean=30.06, median=29.50, std=2.50
#
#
# === Potential Issues Detected ===
#
# WARNING: Column 'red_fighter_defense' has much higher variance in one dataset (ratio: 8.22)
# WARNING: Column 'blue_fighter_defense' has much higher variance in one dataset (ratio: 10.93)

# %% [markdown]
# After manually checking the results, I do not find these hits as differences in measure.

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13285 entries, 0 to 13284
# Data columns (total 85 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   weight_class                                13285 non-null  object
#  1   red_body_attempted_weighted_trailing        13285 non-null  float64
#  2   red_body_landed_weighted_trailing           13285 non-null  float64
#  3   red_clinch_attempted_weighted_trailing      13285 non-null  float64
#  4   red_clinch_landed_weighted_trailing         13285 non-null  float64
#  5   red_ctrl_weighted_trailing                  13285 non-null  float64
#  6   red_distance_attempted_weighted_trailing    13285 non-null  float64
#  7   red_distance_landed_weighted_trailing       13285 non-null  float64
#  8   red_fighter_avg_fight_time                  13285 non-null  float64
#  9   red_fighter_days_since_last                 13285 non-null  int64
#  10  red_fighter_defense                         13285 non-null  float64
#  11  red_fighter_height                          13285 non-null  int64
#  12  red_fighter_losses                          13285 non-null  int64
#  13  red_fighter_name                            13285 non-null  object
#  14  red_fighter_reach                           13285 non-null  int64
#  15  red_fighter_stance                          13285 non-null  object
#  16  red_fighter_strikes_absorbed_per_min        13285 non-null  float64
#  17  red_fighter_strikes_landed_per_min          13285 non-null  float64
#  18  red_fighter_striking_accuracy               13285 non-null  float64
#  19  red_fighter_submission_per_15               13285 non-null  float64
#  20  red_fighter_takedown_accuracy               13285 non-null  float64
#  21  red_fighter_takedown_defense                13285 non-null  float64
#  22  red_fighter_takedowns_per_15                13285 non-null  float64
#  23  red_fighter_weight                          13285 non-null  int64
#  24  red_fighter_wins                            13285 non-null  int64
#  25  red_ground_attempted_weighted_trailing      13285 non-null  float64
#  26  red_ground_landed_weighted_trailing         13285 non-null  float64
#  27  red_head_attempted_weighted_trailing        13285 non-null  float64
#  28  red_head_landed_weighted_trailing           13285 non-null  float64
#  29  red_kd_weighted_trailing                    13285 non-null  float64
#  30  red_leg_attempted_weighted_trailing         13285 non-null  float64
#  31  red_leg_landed_weighted_trailing            13285 non-null  float64
#  32  red_rev_weighted_trailing                   13285 non-null  float64
#  33  red_sig_str_attempted_weighted_trailing     13285 non-null  float64
#  34  red_sig_str_landed_weighted_trailing        13285 non-null  float64
#  35  red_sig_str_pct_weighted_trailing           13285 non-null  float64
#  36  red_sub_att_weighted_trailing               13285 non-null  float64
#  37  red_td_attempted_weighted_trailing          13285 non-null  float64
#  38  red_td_landed_weighted_trailing             13285 non-null  float64
#  39  red_td_pct_weighted_trailing                13285 non-null  float64
#  40  red_total_str_attempted_weighted_trailing   13285 non-null  float64
#  41  red_total_str_landed_weighted_trailing      13285 non-null  float64
#  42  blue_body_attempted_weighted_trailing       13285 non-null  float64
#  43  blue_body_landed_weighted_trailing          13285 non-null  float64
#  44  blue_clinch_attempted_weighted_trailing     13285 non-null  float64
#  45  blue_clinch_landed_weighted_trailing        13285 non-null  float64
#  46  blue_ctrl_weighted_trailing                 13285 non-null  float64
#  47  blue_distance_attempted_weighted_trailing   13285 non-null  float64
#  48  blue_distance_landed_weighted_trailing      13285 non-null  float64
#  49  blue_fighter_avg_fight_time                 13285 non-null  float64
#  50  blue_fighter_days_since_last                13285 non-null  int64
#  51  blue_fighter_defense                        13285 non-null  float64
#  52  blue_fighter_height                         13285 non-null  int64
#  53  blue_fighter_losses                         13285 non-null  int64
#  54  blue_fighter_name                           13285 non-null  object
#  55  blue_fighter_reach                          13285 non-null  int64
#  56  blue_fighter_stance                         13285 non-null  object
#  57  blue_fighter_strikes_absorbed_per_min       13285 non-null  float64
#  58  blue_fighter_strikes_landed_per_min         13285 non-null  float64
#  59  blue_fighter_striking_accuracy              13285 non-null  float64
#  60  blue_fighter_submission_per_15              13285 non-null  float64
#  61  blue_fighter_takedown_accuracy              13285 non-null  float64
#  62  blue_fighter_takedown_defense               13285 non-null  float64
#  63  blue_fighter_takedowns_per_15               13285 non-null  float64
#  64  blue_fighter_weight                         13285 non-null  int64
#  65  blue_fighter_wins                           13285 non-null  int64
#  66  blue_ground_attempted_weighted_trailing     13285 non-null  float64
#  67  blue_ground_landed_weighted_trailing        13285 non-null  float64
#  68  blue_head_attempted_weighted_trailing       13285 non-null  float64
#  69  blue_head_landed_weighted_trailing          13285 non-null  float64
#  70  blue_kd_weighted_trailing                   13285 non-null  float64
#  71  blue_leg_attempted_weighted_trailing        13285 non-null  float64
#  72  blue_leg_landed_weighted_trailing           13285 non-null  float64
#  73  blue_rev_weighted_trailing                  13285 non-null  float64
#  74  blue_sig_str_attempted_weighted_trailing    13285 non-null  float64
#  75  blue_sig_str_landed_weighted_trailing       13285 non-null  float64
#  76  blue_sig_str_pct_weighted_trailing          13285 non-null  float64
#  77  blue_sub_att_weighted_trailing              13285 non-null  float64
#  78  blue_td_attempted_weighted_trailing         13285 non-null  float64
#  79  blue_td_landed_weighted_trailing            13285 non-null  float64
#  80  blue_td_pct_weighted_trailing               13285 non-null  float64
#  81  blue_total_str_attempted_weighted_trailing  13285 non-null  float64
#  82  blue_total_str_landed_weighted_trailing     13285 non-null  float64
#  83  red_fighter_age                             13285 non-null  float64
#  84  blue_fighter_age                            13285 non-null  float64
# dtypes: float64(68), int64(12), object(5)
# memory usage: 8.6+ MB

# %%
cat_cols = [col for col in train.select_dtypes(include=['object']).columns 
            if col not in ['red_fighter_name', 'blue_fighter_name']]

# %%
cat_cols
# Out:
# ['weight_class', 'red_fighter_stance', 'blue_fighter_stance']

# %%
for col in ['red_fighter_stance', 'blue_fighter_stance']:
    print(train[col].value_counts())
    print(validation[col].value_counts())
# Out:
# red_fighter_stance
# Orthodox       9937
# Southpaw       2649
# Switch          675
# Open Stance      22
# Sideways          2
# Name: count, dtype: int64
# red_fighter_stance
# Orthodox    9
# Switch      3
# Southpaw    1
# Name: count, dtype: int64
# blue_fighter_stance
# Orthodox       10021
# Southpaw        2510
# Switch           737
# Open Stance       12
# Sideways           5
# Name: count, dtype: int64
# blue_fighter_stance
# Orthodox    11
# Southpaw     2
# Name: count, dtype: int64

# %% [markdown]
# I remove the women's prefix from dfs. I guess, the GCN will only learn on edges, and I suppose there wont be edges between man and woman fighters.

# %%
validation['weight_class'] = validation['weight_class'].str.replace("Women's", '').str.strip()

# %%
print(train["weight_class"].value_counts())
print(validation["weight_class"].value_counts())
# Out:
# weight_class
# Welterweight         2395
# Lightweight          2076
# Middleweight         1774
# Flyweight            1699
# Bantamweight         1638
# Featherweight        1410
# Heavyweight          1180
# Light Heavyweight    1113
# Name: count, dtype: int64
# weight_class
# Lightweight          3
# Welterweight         2
# Strawweight          2
# Light Heavyweight    1
# Featherweight        1
# Flyweight            1
# Heavyweight          1
# Middleweight         1
# Bantamweight         1
# Name: count, dtype: int64

# %%
validation['weight_class'] = validation['weight_class'].replace('Strawweight', 'Flyweight')

# %%
for cat_col in cat_cols:
    # For multi-category variables, we use One-Hot Encoding. This creates a new binary column for each category, with 1 indicating the presence of that category and 0 otherwise.
    # One-Hot Encoding using pandas get_dummies
    train = pd.get_dummies(train, columns=[cat_col], drop_first=True)
    # Apply One-Hot Encoding to test data
    validation = pd.get_dummies(validation, columns=[cat_col], drop_first=True)

    # Align the train and test datasets to have the same columns
    train, validation = train.align(validation, join='left', axis=1, fill_value=0)

# %%
def convert_int_to_float(df):
    """
    Convert all integer columns in a DataFrame to float.
    
    Parameters:
    -----------
    df : pandas.DataFrame
        DataFrame containing columns to convert
    
    Returns:
    --------
    pandas.DataFrame
        DataFrame with all integer columns converted to float
    """
    # Create a copy to avoid modifying the original
    df_copy = df.copy()
    
    # Get all integer columns
    int_cols = df_copy.select_dtypes(include=['int', 'int16', 'int32', 'int64', "bool"]).columns
    
    # Convert each integer column to float
    for col in int_cols:
        df_copy[col] = df_copy[col].astype(float)
    
    return df_copy

# Example usage:
train = convert_int_to_float(train)
validation = convert_int_to_float(validation)

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13285 entries, 0 to 13284
# Data columns (total 97 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   red_body_attempted_weighted_trailing        13285 non-null  float64
#  1   red_body_landed_weighted_trailing           13285 non-null  float64
#  2   red_clinch_attempted_weighted_trailing      13285 non-null  float64
#  3   red_clinch_landed_weighted_trailing         13285 non-null  float64
#  4   red_ctrl_weighted_trailing                  13285 non-null  float64
#  5   red_distance_attempted_weighted_trailing    13285 non-null  float64
#  6   red_distance_landed_weighted_trailing       13285 non-null  float64
#  7   red_fighter_avg_fight_time                  13285 non-null  float64
#  8   red_fighter_days_since_last                 13285 non-null  float64
#  9   red_fighter_defense                         13285 non-null  float64
#  10  red_fighter_height                          13285 non-null  float64
#  11  red_fighter_losses                          13285 non-null  float64
#  12  red_fighter_name                            13285 non-null  object
#  13  red_fighter_reach                           13285 non-null  float64
#  14  red_fighter_strikes_absorbed_per_min        13285 non-null  float64
#  15  red_fighter_strikes_landed_per_min          13285 non-null  float64
#  16  red_fighter_striking_accuracy               13285 non-null  float64
#  17  red_fighter_submission_per_15               13285 non-null  float64
#  18  red_fighter_takedown_accuracy               13285 non-null  float64
#  19  red_fighter_takedown_defense                13285 non-null  float64
#  20  red_fighter_takedowns_per_15                13285 non-null  float64
#  21  red_fighter_weight                          13285 non-null  float64
#  22  red_fighter_wins                            13285 non-null  float64
#  23  red_ground_attempted_weighted_trailing      13285 non-null  float64
#  24  red_ground_landed_weighted_trailing         13285 non-null  float64
#  25  red_head_attempted_weighted_trailing        13285 non-null  float64
#  26  red_head_landed_weighted_trailing           13285 non-null  float64
#  27  red_kd_weighted_trailing                    13285 non-null  float64
#  28  red_leg_attempted_weighted_trailing         13285 non-null  float64
#  29  red_leg_landed_weighted_trailing            13285 non-null  float64
#  30  red_rev_weighted_trailing                   13285 non-null  float64
#  31  red_sig_str_attempted_weighted_trailing     13285 non-null  float64
#  32  red_sig_str_landed_weighted_trailing        13285 non-null  float64
#  33  red_sig_str_pct_weighted_trailing           13285 non-null  float64
#  34  red_sub_att_weighted_trailing               13285 non-null  float64
#  35  red_td_attempted_weighted_trailing          13285 non-null  float64
#  36  red_td_landed_weighted_trailing             13285 non-null  float64
#  37  red_td_pct_weighted_trailing                13285 non-null  float64
#  38  red_total_str_attempted_weighted_trailing   13285 non-null  float64
#  39  red_total_str_landed_weighted_trailing      13285 non-null  float64
#  40  blue_body_attempted_weighted_trailing       13285 non-null  float64
#  41  blue_body_landed_weighted_trailing          13285 non-null  float64
#  42  blue_clinch_attempted_weighted_trailing     13285 non-null  float64
#  43  blue_clinch_landed_weighted_trailing        13285 non-null  float64
#  44  blue_ctrl_weighted_trailing                 13285 non-null  float64
#  45  blue_distance_attempted_weighted_trailing   13285 non-null  float64
#  46  blue_distance_landed_weighted_trailing      13285 non-null  float64
#  47  blue_fighter_avg_fight_time                 13285 non-null  float64
#  48  blue_fighter_days_since_last                13285 non-null  float64
#  49  blue_fighter_defense                        13285 non-null  float64
#  50  blue_fighter_height                         13285 non-null  float64
#  51  blue_fighter_losses                         13285 non-null  float64
#  52  blue_fighter_name                           13285 non-null  object
#  53  blue_fighter_reach                          13285 non-null  float64
#  54  blue_fighter_strikes_absorbed_per_min       13285 non-null  float64
#  55  blue_fighter_strikes_landed_per_min         13285 non-null  float64
#  56  blue_fighter_striking_accuracy              13285 non-null  float64
#  57  blue_fighter_submission_per_15              13285 non-null  float64
#  58  blue_fighter_takedown_accuracy              13285 non-null  float64
#  59  blue_fighter_takedown_defense               13285 non-null  float64
#  60  blue_fighter_takedowns_per_15               13285 non-null  float64
#  61  blue_fighter_weight                         13285 non-null  float64
#  62  blue_fighter_wins                           13285 non-null  float64
#  63  blue_ground_attempted_weighted_trailing     13285 non-null  float64
#  64  blue_ground_landed_weighted_trailing        13285 non-null  float64
#  65  blue_head_attempted_weighted_trailing       13285 non-null  float64
#  66  blue_head_landed_weighted_trailing          13285 non-null  float64
#  67  blue_kd_weighted_trailing                   13285 non-null  float64
#  68  blue_leg_attempted_weighted_trailing        13285 non-null  float64
#  69  blue_leg_landed_weighted_trailing           13285 non-null  float64
#  70  blue_rev_weighted_trailing                  13285 non-null  float64
#  71  blue_sig_str_attempted_weighted_trailing    13285 non-null  float64
#  72  blue_sig_str_landed_weighted_trailing       13285 non-null  float64
#  73  blue_sig_str_pct_weighted_trailing          13285 non-null  float64
#  74  blue_sub_att_weighted_trailing              13285 non-null  float64
#  75  blue_td_attempted_weighted_trailing         13285 non-null  float64
#  76  blue_td_landed_weighted_trailing            13285 non-null  float64
#  77  blue_td_pct_weighted_trailing               13285 non-null  float64
#  78  blue_total_str_attempted_weighted_trailing  13285 non-null  float64
#  79  blue_total_str_landed_weighted_trailing     13285 non-null  float64
#  80  red_fighter_age                             13285 non-null  float64
#  81  blue_fighter_age                            13285 non-null  float64
#  82  weight_class_Featherweight                  13285 non-null  float64
#  83  weight_class_Flyweight                      13285 non-null  float64
#  84  weight_class_Heavyweight                    13285 non-null  float64
#  85  weight_class_Light Heavyweight              13285 non-null  float64
#  86  weight_class_Lightweight                    13285 non-null  float64
#  87  weight_class_Middleweight                   13285 non-null  float64
#  88  weight_class_Welterweight                   13285 non-null  float64
#  89  red_fighter_stance_Orthodox                 13285 non-null  float64
#  90  red_fighter_stance_Sideways                 13285 non-null  float64
#  91  red_fighter_stance_Southpaw                 13285 non-null  float64
#  92  red_fighter_stance_Switch                   13285 non-null  float64
#  93  blue_fighter_stance_Orthodox                13285 non-null  float64
#  94  blue_fighter_stance_Sideways                13285 non-null  float64
#  95  blue_fighter_stance_Southpaw                13285 non-null  float64
#  96  blue_fighter_stance_Switch                  13285 non-null  float64
# dtypes: float64(95), object(2)
# memory usage: 9.8+ MB

# %%
validation.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13 entries, 0 to 12
# Data columns (total 97 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   red_body_attempted_weighted_trailing        13 non-null     float64
#  1   red_body_landed_weighted_trailing           13 non-null     float64
#  2   red_clinch_attempted_weighted_trailing      13 non-null     float64
#  3   red_clinch_landed_weighted_trailing         13 non-null     float64
#  4   red_ctrl_weighted_trailing                  13 non-null     float64
#  5   red_distance_attempted_weighted_trailing    13 non-null     float64
#  6   red_distance_landed_weighted_trailing       13 non-null     float64
#  7   red_fighter_avg_fight_time                  13 non-null     float64
#  8   red_fighter_days_since_last                 13 non-null     float64
#  9   red_fighter_defense                         13 non-null     float64
#  10  red_fighter_height                          13 non-null     float64
#  11  red_fighter_losses                          13 non-null     float64
#  12  red_fighter_name                            13 non-null     object
#  13  red_fighter_reach                           13 non-null     float64
#  14  red_fighter_strikes_absorbed_per_min        13 non-null     float64
#  15  red_fighter_strikes_landed_per_min          13 non-null     float64
#  16  red_fighter_striking_accuracy               13 non-null     float64
#  17  red_fighter_submission_per_15               13 non-null     float64
#  18  red_fighter_takedown_accuracy               13 non-null     float64
#  19  red_fighter_takedown_defense                13 non-null     float64
#  20  red_fighter_takedowns_per_15                13 non-null     float64
#  21  red_fighter_weight                          13 non-null     float64
#  22  red_fighter_wins                            13 non-null     float64
#  23  red_ground_attempted_weighted_trailing      13 non-null     float64
#  24  red_ground_landed_weighted_trailing         13 non-null     float64
#  25  red_head_attempted_weighted_trailing        13 non-null     float64
#  26  red_head_landed_weighted_trailing           13 non-null     float64
#  27  red_kd_weighted_trailing                    13 non-null     float64
#  28  red_leg_attempted_weighted_trailing         13 non-null     float64
#  29  red_leg_landed_weighted_trailing            13 non-null     float64
#  30  red_rev_weighted_trailing                   13 non-null     float64
#  31  red_sig_str_attempted_weighted_trailing     13 non-null     float64
#  32  red_sig_str_landed_weighted_trailing        13 non-null     float64
#  33  red_sig_str_pct_weighted_trailing           13 non-null     float64
#  34  red_sub_att_weighted_trailing               13 non-null     float64
#  35  red_td_attempted_weighted_trailing          13 non-null     float64
#  36  red_td_landed_weighted_trailing             13 non-null     float64
#  37  red_td_pct_weighted_trailing                13 non-null     float64
#  38  red_total_str_attempted_weighted_trailing   13 non-null     float64
#  39  red_total_str_landed_weighted_trailing      13 non-null     float64
#  40  blue_body_attempted_weighted_trailing       13 non-null     float64
#  41  blue_body_landed_weighted_trailing          13 non-null     float64
#  42  blue_clinch_attempted_weighted_trailing     13 non-null     float64
#  43  blue_clinch_landed_weighted_trailing        13 non-null     float64
#  44  blue_ctrl_weighted_trailing                 13 non-null     float64
#  45  blue_distance_attempted_weighted_trailing   13 non-null     float64
#  46  blue_distance_landed_weighted_trailing      13 non-null     float64
#  47  blue_fighter_avg_fight_time                 13 non-null     float64
#  48  blue_fighter_days_since_last                13 non-null     float64
#  49  blue_fighter_defense                        13 non-null     float64
#  50  blue_fighter_height                         13 non-null     float64
#  51  blue_fighter_losses                         13 non-null     float64
#  52  blue_fighter_name                           13 non-null     object
#  53  blue_fighter_reach                          13 non-null     float64
#  54  blue_fighter_strikes_absorbed_per_min       13 non-null     float64
#  55  blue_fighter_strikes_landed_per_min         13 non-null     float64
#  56  blue_fighter_striking_accuracy              13 non-null     float64
#  57  blue_fighter_submission_per_15              13 non-null     float64
#  58  blue_fighter_takedown_accuracy              13 non-null     float64
#  59  blue_fighter_takedown_defense               13 non-null     float64
#  60  blue_fighter_takedowns_per_15               13 non-null     float64
#  61  blue_fighter_weight                         13 non-null     float64
#  62  blue_fighter_wins                           13 non-null     float64
#  63  blue_ground_attempted_weighted_trailing     13 non-null     float64
#  64  blue_ground_landed_weighted_trailing        13 non-null     float64
#  65  blue_head_attempted_weighted_trailing       13 non-null     float64
#  66  blue_head_landed_weighted_trailing          13 non-null     float64
#  67  blue_kd_weighted_trailing                   13 non-null     float64
#  68  blue_leg_attempted_weighted_trailing        13 non-null     float64
#  69  blue_leg_landed_weighted_trailing           13 non-null     float64
#  70  blue_rev_weighted_trailing                  13 non-null     float64
#  71  blue_sig_str_attempted_weighted_trailing    13 non-null     float64
#  72  blue_sig_str_landed_weighted_trailing       13 non-null     float64
#  73  blue_sig_str_pct_weighted_trailing          13 non-null     float64
#  74  blue_sub_att_weighted_trailing              13 non-null     float64
#  75  blue_td_attempted_weighted_trailing         13 non-null     float64
#  76  blue_td_landed_weighted_trailing            13 non-null     float64
#  77  blue_td_pct_weighted_trailing               13 non-null     float64
#  78  blue_total_str_attempted_weighted_trailing  13 non-null     float64
#  79  blue_total_str_landed_weighted_trailing     13 non-null     float64
#  80  red_fighter_age                             13 non-null     float64
#  81  blue_fighter_age                            13 non-null     float64
#  82  weight_class_Featherweight                  13 non-null     float64
#  83  weight_class_Flyweight                      13 non-null     float64
#  84  weight_class_Heavyweight                    13 non-null     float64
#  85  weight_class_Light Heavyweight              13 non-null     float64
#  86  weight_class_Lightweight                    13 non-null     float64
#  87  weight_class_Middleweight                   13 non-null     float64
#  88  weight_class_Welterweight                   13 non-null     float64
#  89  red_fighter_stance_Orthodox                 13 non-null     float64
#  90  red_fighter_stance_Sideways                 13 non-null     float64
#  91  red_fighter_stance_Southpaw                 13 non-null     float64
#  92  red_fighter_stance_Switch                   13 non-null     float64
#  93  blue_fighter_stance_Orthodox                13 non-null     float64
#  94  blue_fighter_stance_Sideways                13 non-null     float64
#  95  blue_fighter_stance_Southpaw                13 non-null     float64
#  96  blue_fighter_stance_Switch                  13 non-null     float64
# dtypes: float64(95), object(2)
# memory usage: 10.0+ KB

# %%
def scale_features_for_gcn(train_df, validation_df):
    """
    Scale numerical features in a way that's beneficial for GCN training.
    
    For GCNs, we want to:
    1. Normalize features to similar ranges to prevent some features from dominating
    2. Handle outliers that could cause gradient issues
    3. Preserve the relative relationships between features
    
    Parameters:
    -----------
    train_df : pandas.DataFrame
        Training dataset
    validation_df : pandas.DataFrame
        Validation dataset
        
    Returns:
    --------
    train_scaled : pandas.DataFrame
        Scaled training dataset
    validation_scaled : pandas.DataFrame
        Scaled validation dataset
    """
    import pandas as pd
    import numpy as np
    from sklearn.preprocessing import RobustScaler
    
    # Create copies to avoid modifying the originals
    train_scaled = train_df.copy()
    validation_scaled = validation_df.copy()
    
    # Get all float columns
    float_cols = train_df.select_dtypes(include=['float64']).columns
    
    # Exclude one-hot encoded columns (those with stance or weight_class in the name)
    exclude_patterns = ['stance', 'weight_class']
    scale_cols = [col for col in float_cols if not any(pattern in col for pattern in exclude_patterns)]
    
    # Also exclude the target column if it exists
    if 'target' in scale_cols:
        scale_cols.remove('target')
    
    # Use RobustScaler which is less influenced by outliers
    # This is important for fighting statistics which often have extreme values
    scaler = RobustScaler()
    
    # Fit scaler on training data and transform both datasets
    train_scaled[scale_cols] = scaler.fit_transform(train_df[scale_cols])
    validation_scaled[scale_cols] = scaler.transform(validation_df[scale_cols])
    
    # Print some statistics to verify the scaling
    print(f"Scaled {len(scale_cols)} numerical features")
    print("\nScaling summary (training data):")
    print(f"Mean range: [{train_scaled[scale_cols].mean().min():.2f}, {train_scaled[scale_cols].mean().max():.2f}]")
    print(f"Std range: [{train_scaled[scale_cols].std().min():.2f}, {train_scaled[scale_cols].std().max():.2f}]")
    
    return train_scaled, validation_scaled

# Apply scaling
train_scaled, validation_scaled = scale_features_for_gcn(train, validation)
# Out:
# Scaled 76 numerical features
#
# Scaling summary (training data):
# Mean range: [-0.40, 410.87]
# Std range: [0.47, 1317.30]

# %% [markdown]
# # Saving

# %%
train_scaled["target"] = target

# Save the scaled datasets
train_scaled.to_excel("data/train_scaled.xlsx", index=False)
validation_scaled.to_excel("data/validation_scaled.xlsx", index=False)
